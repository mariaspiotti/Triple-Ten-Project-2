# %% [markdown]
# Project: Video Game Sales Forecasting
# Congratulations! You’ve officially completed your first part of the program on the interactive platform. Now it's time to bring together all you've learned so far in your first integrated project, a real-life analytical case study.
#
# When you finish the project, send your work to the project instructor for assessment. They’ll give you feedback within 24 hours. Use the feedback to make changes, then send the new version back to the project instructor.
#
# You might get further feedback on the new version. This is completely normal. It’s not uncommon to go through several cycles of feedback and revision.
#
# Your project will be considered complete once the project instructor approves it.
#
# Project description
# You work for the online store Ice, which sells video games all over the world. User and expert reviews, genres, platforms (e.g. Xbox or PlayStation), and historical data on game sales are available from open sources. You need to identify patterns that determine whether a game succeeds or not. This will allow you to spot potential big winners and plan advertising campaigns.
#
# In front of you is data going back to 2016. Let’s imagine that it’s December 2016 and you’re planning a campaign for 2017.
#
# The important thing is to get experience working with data. It doesn't really matter whether you're forecasting 2017 sales based on data from 2016 or 2027 sales based on data from 2026.
#
# The dataset contains the abbreviation ESRB. The Entertainment Software Rating Board evaluates a game's content and assigns an age rating such as Teen or Mature.
#
# Instructions for completing the project
# Step 1. Open the data file and study the general information
#
# File path:
#
# /datasets/games.csv . Download dataset
#
# Step 2. Prepare the data
#
# Replace the column names (make them lowercase).
# Convert the data to the required types.
# Describe the columns where the data types have been changed and why.
# If necessary, decide how to deal with missing values:
# Explain why you filled in the missing values as you did or why you decided to leave them blank.
# Why do you think the values are missing? Give possible reasons.
# Pay attention to the abbreviation TBD (to be determined). Specify how you intend to handle such cases.
# Calculate the total sales (the sum of sales in all regions) for each game and put these values in a separate column.
# Step 3. Analyze the data
#
# Look at how many games were released in different years. Is the data for every period significant?
# Look at how sales varied from platform to platform. Choose the platforms with the greatest total sales and build a distribution based on data for each year. Find platforms that used to be popular but now have zero sales. How long does it generally take for new platforms to appear and old ones to fade?
# Determine what period you should take data for. To do so, look at your answers to the previous questions. The key criterion is that the data should allow you to build a prognosis for 2017.
# Work only with the data that you've decided is relevant. Disregard the data for previous years.
# Which platforms are leading in sales? Which ones are growing or shrinking? Select several potentially profitable platforms.
# Build a box plot for the global sales of all games, broken down by platform. Are the differences in sales significant? What about average sales on various platforms? Describe your findings.
# Take a look at how user and professional reviews affect sales for one popular platform (you choose). Build a scatter plot and calculate the correlation between reviews and sales. Draw conclusions.
# Keeping your conclusions in mind, compare the sales of the same games on other platforms.
# Take a look at the general distribution of games by genre. What can we say about the most profitable genres? Can you generalize about genres with high and low sales?
# Step 4. Create a user profile for each region
#
# For each region (NA, EU, JP), determine:
#
# The top five platforms. Describe variations in their market shares from region to region.
# The top five genres. Explain the difference.
# Do ESRB ratings affect sales in individual regions?
# Step 5. Test the following hypotheses:
#
# Average user ratings of the Xbox One and PC platforms are the same.
# Average user ratings for the Action and Sports genres are different.
# Set the alpha threshold value yourself.
#
# Explain:
#
# How you formulated the null and alternative hypotheses.
# What criteria you used to test the hypotheses and why.
# Step 6. Write a general conclusion
#
# Format: Complete the task in the Jupyter Notebook. Insert the programming code in the code cells and text explanations in the markdown cells. Apply formatting and add headings.
#
# Data description
# —Name
#
# —Platform
#
# —Year_of_Release
#
# —Genre
#
# —NA_sales (North American sales in USD million)
#
# —EU_sales (sales in Europe in USD million)
#
# —JP_sales (sales in Japan in USD million)
#
# —Other_sales (sales in other countries in USD million)
#
# —Critic_Score (maximum of 100)
#
# —User_Score (maximum of 10)
#
# —Rating (ESRB)
#
# Data for 2016 may be incomplete.
#
# How will my project be evaluated?
# Read these project assessment criteria carefully before you get to work.
#
# Here’s what project instructors will be looking at at when evaluating your project:
#
# How do you describe the problems you identify in the data?
# How do you prepare a dataset for analysis?
# How do you build distribution graphs and how do you explain them?
# How do you calculate standard deviation and variance?
# Do you formulate alternative and null hypotheses?
# What methods do you apply when testing them?
# Do you explain the results of your hypothesis tests?
# Do you follow the project structure and keep your code neat and comprehensible?
# Which conclusions do you reach?
# Did you leave clear, relevant comments at each step?
# Everything you need to complete this project is in the takeaway sheets and summaries from previous chapters.
#
# Good luck!

# %% [markdown]
# ## Importing Libraries -  Reading the CSV Files - Refining Parameters for the read_csv function.

# %%
import pandas as pd #importing pandas libraries
import matplotlib.pyplot as plt #importing matplotlib libraries
import numpy as np #importing numpy libraries

# %% [markdown]
# ### Orders - Reading the '/datasets/instacart_orders.csv' Dataframe

# %%
orders = pd.read_csv('/datasets/instacart_orders.csv') # this is an intial read of the dataframe to inspect its structure
print(orders.head())
print(orders.info())
# Out:
#   order_id;user_id;order_number;order_dow;order_hour_of_day;days_since_prior_order
# 0                        1515936;183418;11;6;13;30.0
# 1                          1690866;163593;5;5;12;9.0
# 2                           1454967;39980;4;5;19;2.0
# 3                         1768857;82516;56;0;20;10.0
# 4                         3007858;196724;2;4;12;17.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 1 columns):
#  #   Column                                                                            Non-Null Count   Dtype
# ---  ------                                                                            --------------   -----
#  0   order_id;user_id;order_number;order_dow;order_hour_of_day;days_since_prior_order  478967 non-null  object
# dtypes: object(1)
# memory usage: 3.7+ MB
# None

# %%
# Making adjustments to assure that the data is being parsed correctly.
# I used the parameter header=0 of the read_csv() function to make the columns row the header of the dataframe.
# To enssure that no column is used as the index automatically, I used index_col=False.
# The separator or delimiter in the orders dataframe is ':' which is not the default parameter of the read_csv function.
# I used the sep=';' to also ensure that the data is being parsed correctly.

orders = pd.read_csv(
    '/datasets/instacart_orders.csv',
    sep=';',
    header=0,
    decimal=',',
    index_col=False
)

print(orders.info(show_counts=True)) 
"""
because this is a big dataframe I used the parameter show_counts for the .info() method
to ensure that the info() funtion returns the non null count for each column

"""
print(orders.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  object
# dtypes: int64(5), object(1)
# memory usage: 21.9+ MB
# None
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# ...

# %% [markdown]
# *** After printing the info for the orders dataframe I noticed that the 'days_since_prior_order' column is not of int64 type and that the Non-Null count for this column is smaller than the Rangeindex entries indicating that this column has either missing values or values that have not been formatted correctly as integers. ***

# %%
orders.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# 4   3007858   196724             2          4                 12
#
#   days_since_prior_order
# 0                   30.0
# 1                    9.0
# 2                    2.0
# 3                   10.0
# 4                   17.0

# %% [markdown]
# ### Products - Reading the '/datasets/products.csv' Dataframe

# %%
products = pd.read_csv('/datasets/products.csv')  # this is an intial read of the data frame to inspect its structure
print(products.info())
print(products.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 1 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   product_id;product_name;aisle_id;department_id  49694 non-null  object
# dtypes: object(1)
# memory usage: 388.4+ KB
# None
#       product_id;product_name;aisle_id;department_id
# 0                 1;Chocolate Sandwich Cookies;61;19
# 1                          2;All-Seasons Salt;104;13
# 2        3;Robust Golden Unsweetened Oolong Tea;94;7
# 3  4;Smart Ones Classic Favorites Mini Rigatoni W...
# 4                   5;Green Chile Anytime Sauce;5;13

# %%
# Making adjustments to assure that the data is being parsed correctly.
products=pd.read_csv('/datasets/products.csv',
                    sep=';',                  
                    header=0,
                    index_col=False)
print(products.info())
print(products.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
# None
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# ...

# %% [markdown]
# ### Aisles - Reading the '/datasets/aisles.csv' Dataframe

# %%
aisles = pd.read_csv('/datasets/aisles.csv')  # this is an intial read of the data frame to inspect its structure
print(aisles.info())
print(aisles.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   aisle_id;aisle  134 non-null    object
# dtypes: object(1)
# memory usage: 1.2+ KB
# None
#                  aisle_id;aisle
# 0       1;prepared soups salads
# 1           2;specialty cheeses
# 2         3;energy granola bars
# 3               4;instant foods
# 4  5;marinades meat preparation

# %%
# Making adjustments to assure that the data is being parsed correctly.
aisle=pd.read_csv('/datasets/aisles.csv',
                    sep=';',
                    names=['aisles_id', 'aisle'],
                    header=0,
                    index_col=False)
print(aisles.info())
print(aisles.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   aisle_id;aisle  134 non-null    object
# dtypes: object(1)
# memory usage: 1.2+ KB
# None
#                  aisle_id;aisle
# 0       1;prepared soups salads
# 1           2;specialty cheeses
# 2         3;energy granola bars
# 3               4;instant foods
# 4  5;marinades meat preparation

# %% [markdown]
# ### Departments - Reading the '/datasets/departments.csv' Dataframe

# %%
departments = pd.read_csv ('/datasets/departments.csv')  # this is an intial read of the data frame to inspect its structure
print(departments.info())
print(departments.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 1 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   department_id;department  21 non-null     object
# dtypes: object(1)
# memory usage: 296.0+ bytes
# None
#   department_id;department
# 0                 1;frozen
# 1                  2;other
# 2                 3;bakery
# 3                4;produce
# 4                5;alcohol

# %%
# Making adjustments to assure that the data is being parsed correctly.
deparments=pd.read_csv('/datasets/departments.csv',
                    sep=';',
                    header=0,
                    index_col=False)
print(departments.info())
print(departments.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 1 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   department_id;department  21 non-null     object
# dtypes: object(1)
# memory usage: 296.0+ bytes
# None
#   department_id;department
# 0                 1;frozen
# 1                  2;other
# 2                 3;bakery
# 3                4;produce
# 4                5;alcohol

# %% [markdown]
# ### Order Products - Reading the '/datasets/order_products.csv' Dataframe

# %%
order_products = pd.read_csv ('/datasets/order_products.csv')  # this is an intial read of the data frame to inspect its structure
print(order_products.info())
print(order_products.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 1 columns):
#  #   Column                                           Dtype
# ---  ------                                           -----
#  0   order_id;product_id;add_to_cart_order;reordered  object
# dtypes: object(1)
# memory usage: 34.7+ MB
# None
#   order_id;product_id;add_to_cart_order;reordered
# 0                            2141543;11440;17.0;0
# 1                               567889;1560;1.0;1
# 2                             2261212;26683;1.0;1
# 3                              491251;8670;35.0;1
# 4                              2571142;1940;5.0;1

# %%
# Making adjustments to assure that the data is being parsed correctly.
order_products=pd.read_csv('/datasets/order_products.csv',
                    sep=';',
                    header=0,
                    index_col=False)
print(order_products.info())
print(order_products.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  float64
#  3   reordered          int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB
# None
#    order_id  product_id  add_to_cart_order  reordered
# 0   2141543       11440               17.0          0
# 1    567889        1560                1.0          1
# 2   2261212       26683                1.0          1
# 3    491251        8670               35.0          1
# 4   2571142        1940                5.0          1

# %% [markdown]
# ## Finding and removing duplicate values.

# %% [markdown]
# ### `orders` data frame

# %%
# Check for duplicated orders
#cheking for fully duplicated rows
duplicates=orders.duplicated().sum() 
print(duplicates)
# Out:
# 15

# %% [markdown]
# #### From the output of the previous cell I have learned that there are 15 fully duplicated rows in the orders dataframe.

# %%
# Check for all orders placed Wednesday at 2:00 AM
# Filtering the orders dataframe by the required condition and storing the new dataframe in a new variable
wednesday_orders_at_2am = orders[(orders['order_dow'] == 3) & (orders['order_hour_of_day'] == 2)]
print(wednesday_orders_at_2am)
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838     2766110   162084            41          3                  2
# 5156     2190225   138285            18          3                  2
# 15506     553049    58599            13          3                  2
# 18420     382357   120200            19          3                  2
# 24691     690242    77357             2          3                  2
# ...          ...      ...           ...        ...                ...
# 457013   3384021    14881             6          3                  2
# 458816    910166   164782            18          3                  2
# 459635   1680532   106435             6          3                  2
# 468324    222962    54979            59          3                  2
# 477526   2592344    46860            38          3                  2
#
#        days_since_prior_order
# 4838                     16.0
# 5156                     11.0
# 15506                     7.0
# ...

# %%
# Remove duplicate orders
""" To remove duplicates orders I will use the drop_duplicates method with no parameters 
because I want to remove all fully duplicated orders."""
orders=orders.drop_duplicates()
print(orders)
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0        1515936   183418            11          6                 13
# 1        1690866   163593             5          5                 12
# 2        1454967    39980             4          5                 19
# 3        1768857    82516            56          0                 20
# 4        3007858   196724             2          4                 12
# ...          ...      ...           ...        ...                ...
# 478962   3210681     5617             5          1                 14
# 478963   3270802   112087             2          3                 13
# 478964    885349    82944            16          2                 11
# 478965    216274     4391             3          3                  8
# 478966   2071924     1730            18          1                 14
#
#        days_since_prior_order
# 0                        30.0
# 1                         9.0
# 2                         2.0
# ...

# %%
# Double check for duplicate rows
# To duple check for duplicate rows I will run the .duplicated() and .sun() methods on the orders_D_dropped dataframe. 
duplicates=orders.duplicated().sum()
print(duplicates)
# Out:
# 0

# %%
# Double check for duplicate order IDs only
# To duble check for duplicate order IDs I will use the .duplicated() and .sum() methods on the orders_D_dropped dataframe
# I will use the subset parameter to indicate the column that I want to check.
# This is a necessary step because all order IDs values should be unique values.
duplicate_order_id=orders.duplicated(subset=['order_id']).sum()
print(duplicate_order_id)
# there are 0 rows with duplicate order ids
# Out:
# 0

# %% [markdown]
# ### `products` data frame

# %%
# Check for fully duplicate rows
duplicates=products.duplicated().sum() 
print(duplicates)
# The "products" dataframe has no fully duplicate rows
# Out:
# 0

# %%
# Check for just duplicate product IDs
duplicate_product_id=products.duplicated(subset=['product_id']).sum()
print(duplicate_product_id)
# There are 0 rows with a duplicate product id.
# Out:
# 0

# %%
# Check for just duplicate product names (convert names to lowercase to compare better)
duplicate_product_name = products['product_name'].str.lower().duplicated().sum()
print(duplicate_product_name)
# Out:
# 1361

# %% [markdown]
# #### The 'products' dataframe contains a total of 49694 entries. 1361 of these entries could have a duplicate product name. At this point we do not know how many of the counted duplicated names (in our case 1361) are not in fact missing values that should be filtered out. In the next cell we check for duplicate product names that aren't missing values.

# %%
# Check for duplicate product names that aren't missing
duplicate_product_name = products['product_name'].dropna().str.lower().duplicated().sum()
print(duplicate_product_name)
# Out:
# 104

# %% [markdown]
# There are 104 duplicate product names that aren't missing values.

# %% [markdown]
# ### `departments` data frame

# %%
# Checing for fully duplicated rows in the "departments" dataframe
duplicates=departments.duplicated().sum()
print(duplicates)
# Out:
# 0

# %%
duplicate_departments = departments.duplicated(subset=['department_id;department']).sum()
print(duplicate_departments)
# Out:
# 0

# %% [markdown]
# There are no fully duplicated rows in the "departments" dataframe. There are no duplicate values in the "department_id_department" column

# %% [markdown]
# ### `aisles` data frame

# %%
duplicates=aisles.duplicated().sum()
print(duplicates)
# Out:
# 0

# %%
duplicate_aisles = aisles.duplicated(subset=['aisle_id;aisle']).sum()

print(f"Fully duplicated rows in the 'aisles' dataframe:{duplicate_aisles}")
# Out:
# Fully duplicated rows in the 'aisles' dataframe:0

# %% [markdown]
# There are no fully duplicated rows in the "aisles" dataframe. There are no duplicate values in the "aisles_id" column

# %% [markdown]
# ### `order_products` data frame

# %%
# Check for duplicate order products
duplicates=order_products.duplicated().sum()
print(f"Fully Duplicated Rows in the 'order_products' dataframe:{duplicates}")
# Out:
# Fully Duplicated Rows in the 'order_products' dataframe:0

# %%
# Double check for any other tricky duplicates
# Checking for duplicate orders:
duplicate_orders = order_products['order_id'].duplicated().sum()
print(f"Duplicate orders: {duplicate_orders}")
# Checking for duplicate product_ids:
duplicate_products = order_products['product_id'].duplicated().sum()
print(f"Duplicate products: {duplicate_products}")
duplicate_order_product = order_products.duplicated(subset=['order_id', 'product_id']).sum()
print(f"Duplicate order product pairs: {duplicate_order_product}")
# Checking for reordered duplicates
reordered_duplicates = order_products[order_products['reordered'] == 1].duplicated(subset=['order_id', 'product_id']).sum()
print(f"Duplicate reordered products: {reordered_duplicates}")
# Out:
# Duplicate orders: 4094961
# Duplicate products: 4499434
# Duplicate order product pairs: 0
# Duplicate reordered products: 0

# %% [markdown]
# No Duplicate Order-Product Pairs is a positive sign indicating that data structure for order-product associations is functioning correctly. No Duplicate Reordered Products (0) is also a good sign.

# %% [markdown]
# ## Find and remove missing values

# %% [markdown]
# ### `products` data frame

# %%
# Checking for missing vavues in each row
missing_values = products.isnull().sum()
print("Missing values in each column:")
print(missing_values)

# Dropping rows with missing values
products_cleaned = products.dropna()

#Verifying the shape of the cleaned DataFrame
print("Shape of cleaned DataFrame:", products_cleaned.shape)

# Resetting the index after dropping rows
products_cleaned.reset_index(drop=True, inplace=True)

#Displaying the cleaned DataFrame
print(products_cleaned.head())
# Out:
# Missing values in each column:
# product_id          0
# product_name     1258
# aisle_id            0
# department_id       0
# dtype: int64
# Shape of cleaned DataFrame: (48436, 4)
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
# Are all of the missing product names associated with aisle ID 100?
# Filtering for missing product names
missing_product_names = products[products['product_name'].isnull()]

# Checking if all aisle IDs in this filtered DataFrame are 100
all_missing_are_100 = (missing_product_names['aisle_id'] == 100).all()

# Outputing the result
if all_missing_are_100:
    print("All missing product names are associated with aisle ID 100.")
else:
    print("Not all missing product names are associated with aisle ID 100.")
# Out:
# All missing product names are associated with aisle ID 100.

# %%
# Are all of the missing product names associated with department ID 21?
# Filtering for missing product names
missing_product_names = products[products['product_name'].isnull()]

# Checking if all department IDs in this filtered DataFrame are 21
all_missing_are_21 = (missing_product_names['department_id'] == 21).all()

# Outputing the result
if all_missing_are_21:
    print("All missing product names are associated with department ID 21.")
else:
    print("Not all missing product names are associated with department ID 21.")
# Out:
# All missing product names are associated with department ID 21.

# %%
# What is this ailse and department?
# Spliting the aisles DataFrame
aisles[['aisle_id', 'aisle_name']] = aisles['aisle_id;aisle'].str.split(';', expand=True)
aisles['aisle_id'] = aisles['aisle_id'].astype(int)  # Convert aisle_id to int

# Spliting the departments DataFrame
departments[['department_id', 'department_name']] = departments['department_id;department'].str.split(';', expand=True)
departments['department_id'] = departments['department_id'].astype(int)  # Converting department_id to int

# Extracting the names for aisle_id 100 and department_id 21
aisle_name = aisles.loc[aisles['aisle_id'] == 100, 'aisle_name'].values[0]
department_name = departments.loc[departments['department_id'] == 21, 'department_name'].values[0]

# Display the results
print(f"Aisle Name: {aisle_name}")
print(f"Department Name: {department_name}")
# Out:
# Aisle Name: missing
# Department Name: missing

# %%
## Fill missing product names with 'Unknown'
# Filling missing product names with 'Unknown'
products['product_name'] = products['product_name'].fillna('Unknown')

# Displaying the updated DataFrame
print(products)
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49689       49690                      HIGH PERFORMANCE ENERGY DRINK
# 49690       49691                      ORIGINAL PANCAKE & WAFFLE MIX
# 49691       49692    ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR
# 49692       49693                             SPRING WATER BODY WASH
# 49693       49694                            BURRITO- STEAK & CHEESE
#
#        aisle_id  department_id
# 0            61             19
# 1           104             13
# 2            94              7
# ...

# %% [markdown]
# ### `orders` data frame

# %%
# Checking for missing vavues in each row
missing_values = orders.isnull().sum()
print("Missing values in each column:")
print(missing_values)

# Dropping rows with missing values
orders_cleaned = orders.dropna()

#Verifying the shape of the cleaned DataFrame
print("Shape of cleaned DataFrame:", orders_cleaned.shape)

# Resetting the index after dropping rows
orders_cleaned.reset_index(drop=True, inplace=True)

#Displaying the cleaned DataFrame
print(orders_cleaned.head())
# Out:
# Missing values in each column:
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28817
# dtype: int64
# Shape of cleaned DataFrame: (450135, 6)
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# 4   3007858   196724             2          4                 12
#
#   days_since_prior_order
# 0                   30.0
# 1                    9.0
# 2                    2.0
# 3                   10.0
# 4                   17.0

# %%
# Are there any missing values where it's not a customer's first order?
# Identifying the first order for each customer
first_order = orders.groupby('user_id')['order_number'].min().reset_index()
first_order.columns = ['user_id', 'first_order_number']

# Merging to identify non-first orders
merged_df = pd.merge(orders, first_order, on=['user_id'], how='left')

# Filtering for non-first orders
non_first_orders = merged_df[merged_df['order_number'] > merged_df['first_order_number']]

# Checking for missing values in 'days_since_prior_order'
missing_non_first = non_first_orders['days_since_prior_order'].isnull().sum()

# Outputing the result
print(f"Number of missing values in 'days_since_prior_order' for non-first orders: {missing_non_first}")
# Out:
# Number of missing values in 'days_since_prior_order' for non-first orders: 0

# %% [markdown]
# ### `order_products` data frame

# %%
# Checking for missing vavues in each row
missing_values = order_products.isnull().sum()
print("Missing values in each column:")
print(missing_values)

# Dropping rows with missing values
order_products_cleaned = orders.dropna()

#Verifying the shape of the cleaned DataFrame
print("Shape of cleaned DataFrame:", order_products_cleaned.shape)

# Resetting the index after dropping rows
order_products_cleaned.reset_index(drop=True, inplace=True)

#Displaying the cleaned DataFrame
print(order_products_cleaned.head())
# Out:
# Missing values in each column:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64
# Shape of cleaned DataFrame: (450135, 6)
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# 4   3007858   196724             2          4                 12
#
#   days_since_prior_order
# 0                   30.0
# 1                    9.0
# 2                    2.0
# 3                   10.0
# 4                   17.0

# %%
# What are the min and max values in this column?
# I do not know which column I have to look at but I assume it is the columns with missing values

# Dropping missing values in 'add_to_cart_order' for accurate min/max calculation
cleaned_add_to_cart_order = order_products['add_to_cart_order'].dropna()

# Calculating min and max values
min_value = cleaned_add_to_cart_order.min()
max_value = cleaned_add_to_cart_order.max()

# Outputing the results
print(f"Minimum value in 'add_to_cart_order': {min_value}")
print(f"Maximum value in 'add_to_cart_order': {max_value}")
# Out:
# Minimum value in 'add_to_cart_order': 1.0
# Maximum value in 'add_to_cart_order': 64.0

# %%
# Save all order IDs with at least one missing value in 'add_to_cart_order'
# Filtering for rows where 'add_to_cart_order' is missing
missing_values = order_products[order_products['add_to_cart_order'].isnull()]

# Extracting unique order IDs
unique_order_ids_with_missing = missing_values['order_id'].unique()

# Converting to a DataFrame
missing_order_ids_df = pd.DataFrame(unique_order_ids_with_missing, columns=['order_id'])

# Outputing the result
print(missing_order_ids_df)
# Out:
#     order_id
# 0    2449164
# 1    1968313
# 2    2926893
# 3    1717990
# 4    1959075
# ..       ...
# 65      9310
# 66   2170451
# 67   2979697
# 68   1625713
# 69   1529171
#
# [70 rows x 1 columns]

# %%
# Do all orders with missing values have more than 64 products?
# Identifying orders with missing values in 'add_to_cart_order'
missing_values_orders = order_products[order_products['add_to_cart_order'].isnull()]['order_id'].unique()

# Counting the number of products for each order ID
product_counts = order_products[order_products['order_id'].isin(missing_values_orders)]
product_counts = product_counts.groupby('order_id').size()

# Checking if all of these orders have more than 64 products
all_more_than_64 = (product_counts > 64).all()

# Outputing the result
print(f"Do all orders with missing values have more than 64 products? {all_more_than_64}")
# Out:
# Do all orders with missing values have more than 64 products? True

# %%
# Replace missing values with 999 and convert column to integer type
# Replacing missing values with 999
order_products['add_to_cart_order'] = order_products['add_to_cart_order'].fillna(999)

# Converting the column to integer type
order_products['add_to_cart_order'] = order_products['add_to_cart_order'].astype(int)

# Outputing the modified DataFrame
print(order_products)
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 0         2141543       11440                 17          0
# 1          567889        1560                  1          1
# 2         2261212       26683                  1          1
# 3          491251        8670                 35          1
# 4         2571142        1940                  5          1
# ...           ...         ...                ...        ...
# 4545002    577211       15290                 12          1
# 4545003   1219554       21914                  9          0
# 4545004    692640       47766                  4          1
# 4545005    319435         691                  8          1
# 4545006   1398151       28733                  9          0
#
# [4545007 rows x 4 columns]

# %% [markdown]
# # [A] Easy (must complete all to pass)

# %% [markdown]
# ### [A1] Verify that the `'order_hour_of_day'` and `'order_dow'` values in the `orders` tables are sensible (i.e. `'order_hour_of_day'` ranges from 0 to 23 and `'order_dow'` ranges from 0 to 6)

# %%
#Checking for out-of-range values in 'order_hour_of_day'
hour_out_of_range = orders[(orders['order_hour_of_day'] < 0) | (orders['order_hour_of_day'] > 23)]
#Outputing the results
if not hour_out_of_range.empty:
    print("Out-of-range values found in 'order_hour_of_day':")
    print(hour_out_of_range)
else:
    print("All 'order_hour_of_day' values are within the valid range (0-23).")
# Out:
# All 'order_hour_of_day' values are within the valid range (0-23).

# %%
# Checking for out-of-range values in 'order_dow'
dow_out_of_range = orders[(orders['order_dow'] < 0) | (orders['order_dow'] > 6)]
# Outputing the result
if not dow_out_of_range.empty:
    print("Out-of-range values found in 'order_dow':")
    print(dow_out_of_range)
else:
    print("All 'order_dow' values are within the valid range (0-6).")
# Out:
# All 'order_dow' values are within the valid range (0-6).

# %% [markdown]
# ### [A2] What time of day do people shop for groceries?

# %%
# Count the number of orders for each hour of the day
hourly_counts = orders['order_hour_of_day'].value_counts().sort_index()

# Ploting the results
hourly_counts.plot(kind="bar",
                   figsize=(8, 4),
                   color='skyblue',
                  xlabel='Hour of Day',
                  ylabel='Number of Orders',
                  title='Number of Grocery Orders by Hour of Day')
plt.show()

# %% [markdown]
# ####
# The chart indicates that the peak shopping hours for grocery orders are in the late morning and early afternoon, specifically between 9 AM and 4 PM. The number of orders during this time frame is significantly higher compared to other hours of the day.
# This information could be valuable for retailers to optimize staffing, inventory management, and marketing strategies to cater to the shopping habits of their customers.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Reviewer's comment</b> <a
# class="tocSkip"></a>
# Super barplot and right conclusion</div>

# %% [markdown]
# ### [A3] What day of the week do people shop for groceries?

# %%
daily_counts = orders['order_dow'].value_counts().sort_index()

# Ploting the results
daily_counts.plot(kind="bar",
                   figsize=(8, 4),
                   color='skyblue',
                  xlabel='Hour of Day',
                  ylabel='Number of Orders',
                  title='Number of Grocery Orders by Day of Week')
plt.show()

# %% [markdown]
# People tend to shop for groceries on all days of the week but Mondays and Tuesdays are the days when people tend to shop more than any other days of the week.

# %% [markdown]
# ### [A4] How long do people wait until placing another order?

# %%
days_counts = orders['days_since_prior_order'].value_counts().sort_index()

# Converting index to float, then integer
days_counts.index = days_counts.index.astype(float).astype(int)
days_counts = days_counts.sort_index()
# Plotting the results
days_counts.plot(
    kind="bar",
    figsize=(10, 5),
    color='skyblue'
)

plt.xlabel('Days Since Prior Order')
plt.ylabel('Number of Orders')
plt.title('Days Since Prior Order')
plt.xticks(rotation=45, fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# The distribution of days between orders shows a wide range, with a significant number of orders placed within every 7 or less days of the previous order, as well as a long tail of orders placed much later. The peak around 30 days is indicating that many customers tend to place orders roughly once a month. This suggests that the customer base exhibits diverse ordering patterns, with some placing frequent orders and others being more sporadic in their purchasing behavior. Understanding these nuances in the order frequency distribution can help the business optimize inventory management, marketing strategies, and customer engagement to better serve the varied needs of their customer base.

# %% [markdown]
# # [B] Medium (must complete all to pass)

# %% [markdown]
# ### [B1] Is there a difference in `'order_hour_of_day'` distributions on Wednesdays and Saturdays? Plot the histograms for both days and describe the differences that you see.

# %%
#Filter the data to get Wednesdays and Saturdays
wednesday_orders = orders[orders['order_dow'] == 2]['order_hour_of_day']

# %%
saturday_orders = orders[orders['order_dow'] == 5]['order_hour_of_day']

# %%
# Ploting the results
wednesday_orders.plot(
    kind="hist",
    figsize=(8, 4),
    color='blue',
    bins=24,  # One bin per hour
    rwidth=0.8  # Adjusts bin width for better visibility
)

plt.xlabel('Order Hour of Day')
plt.ylabel('Frequency')
plt.title('Order Hour Distribution on Wednesdays')
plt.xticks(range(0, 24))  # Sets x-axis ticks from 0 to 23 for hours
plt.show()
saturday_orders.plot(
    kind="hist",
    figsize=(8, 4),
    color='green',
    bins=24,  # One bin per hour
    rwidth=0.8
)

plt.xlabel('Order Hour of Day')
plt.ylabel('Frequency')
plt.title('Order Hour Distribution on Saturdays')
plt.xticks(range(0, 24))  # Set x-axis ticks from 0 to 23 for hours
plt.show()

# %% [markdown]
# ####
# On Wednesdays, the order volume peaks around 11 AM to 2 PM, while on Saturdays, the peak is earlier, around 10 AM to 1 PM. The overall order volume is higher on Wednesdays compared to Saturdays, with a maximum frequency of around 4,800 orders on Wednesdays versus around 4,300 orders on Saturdays.There are fewer orders in the evening hours (after 6 PM) on Saturdays compared to Wednesdays. These differences suggest that customer ordering patterns vary between weekdays and weekends, with Wednesdays seeing a higher overall volume and a later peak in order activity compared to Saturdays. Understanding these distribution patterns can help the business optimize staffing, inventory management, and other operational aspects to better serve customers on different days of the week.

# %% [markdown]
# ### [B2] What's the distribution for the number of orders per customer?

# %%
#Counting the number of orders per customer
orders_per_customer = orders.groupby('user_id')['order_id'].count()

# %%
# Plotting the distribution
plt.figure(figsize=(8, 4))

# Use orders_per_customer instead of data
plt.hist(orders_per_customer, color='pink', bins=12, rwidth=0.8)

plt.title('Distribution of Number of Orders per Customer')
plt.xlabel('Number of Orders')
plt.ylabel('Frequency')
plt.grid()
plt.show()

# %% [markdown]
# #### The majority of customers seem to have between 0 to 5 orders, as indicated by the tall bar on the left side of the graph.  There are a few customers who have a significantly higher number of orders, as indicated by the smaller bars on the right side of the graph.

# %% [markdown]
# ### [B3] What are the top 20 popular products (display their id and name)?

# %%
#Merging the DataFrames
merged_data = pd.merge(order_products, products, on='product_id')

# %%
#Grouping by product_id and product_name to count orders
product_counts = merged_data.groupby(['product_id', 'product_name']).size().reset_index(name='order_count')

# %%
# Sorting the products by order_count in descending order and get the top 20
top_products = product_counts.sort_values(by='order_count', ascending=False).head(20)

# Displaying the result
print(top_products)
# Out:
#        product_id              product_name  order_count
# 22808       24852                    Banana        66050
# 12025       13176    Bag of Organic Bananas        53297
# 19370       21137      Organic Strawberries        37039
# 20077       21903      Organic Baby Spinach        33971
# 43271       47209      Organic Hass Avocado        29773
# 43788       47766           Organic Avocado        24689
# 43663       47626               Large Lemon        21495
# 15364       16797              Strawberries        20018
# 24047       26209                     Limes        19690
# 25556       27845        Organic Whole Milk        19600
# 25666       27966       Organic Raspberries        19197
# 21025       22935      Organic Yellow Onion        15898
# 22908       24964            Organic Garlic        15292
# 41244       45007          Organic Zucchini        14584
# 35996       39275       Organic Blueberries        13879
# ...

# %% [markdown]
# ####

# %% [markdown]
# # [C] Hard (must complete at least two to pass)

# %% [markdown]
# ### [C1] How many items do people typically buy in one order? What does the distribution look like?

# %%
order_products_count = order_products.groupby('order_id').size()

# %%
# Ploting the distribution
plt.figure(figsize=(8, 4))

# %%
# Creating the histogram
plt.hist(order_products_count, color='blue', bins=30)

plt.title('Distribution of Number of Items per Order')
plt.xlabel('Number of Items')
plt.ylabel('Frequency')
plt.grid()
plt.show()

# %% [markdown]
# ### [C2] What are the top 20 items that are reordered most frequently (display their names and product IDs)?

# %%
# Counting the number of times each product is reordered
reorder_counts = order_products[order_products['reordered'] == 1].groupby('product_id').size().sort_values(ascending=False)

# %%
# Merging the product names from the 'products' DataFrame
top_reordered_items = pd.merge(reorder_counts.to_frame('reorder_count'), products[['product_id', 'product_name']], on='product_id')

# %%
# Displaying the top 20 most frequently reordered items
print(top_reordered_items.head(20))
# Out:
#     product_id  reorder_count              product_name
# 0        24852          55763                    Banana
# 1        13176          44450    Bag of Organic Bananas
# 2        21137          28639      Organic Strawberries
# 3        21903          26233      Organic Baby Spinach
# 4        47209          23629      Organic Hass Avocado
# 5        47766          18743           Organic Avocado
# 6        27845          16251        Organic Whole Milk
# 7        47626          15044               Large Lemon
# 8        27966          14748       Organic Raspberries
# 9        16797          13945              Strawberries
# 10       26209          13327                     Limes
# 11       22935          11145      Organic Yellow Onion
# 12       24964          10411            Organic Garlic
# 13       45007          10076          Organic Zucchini
# 14       49683           9538            Cucumber Kirby
# 15       28204           8989        Organic Fuji Apple
# ...

# %% [markdown]
# ####
# The top reordered products are "Banana" with 55,763 reorders, "Bag of Organic Bananas" with 44,450 reorders, and "Organic Strawberries" with 28,639 reorders. These products seem to be very popular with customers and have a high rate of repeat purchases.The data on reorder counts can help the business better understand customer demand and plan inventory accordingly, ensuring they have sufficient stock of the most popular reordered items.

# %% [markdown]
# ### [C3] For each product, what proportion of its orders are reorders?

# %%
# Calculating the total number of orders for each product
total_orders = order_products.groupby('product_id').size()

# %%
# Calculating the number of reorders for each product
reorders = order_products[order_products['reordered'] == 1].groupby('product_id').size()

# %%
# Calculating the reorder proportion for each product
reorder_proportions = (reorders / total_orders).to_frame('reorder_proportion')

# %%
# Merging the product names from the 'products' DataFrame & Displaying the results
product_reorder_proportions = pd.merge(reorder_proportions, products[['product_id', 'product_name']], on='product_id')
print(product_reorder_proportions)
# Out:
#        product_id  reorder_proportion  \
# 0               1            0.564286
# 1               2                 NaN
# 2               3            0.738095
# 3               4            0.510204
# 4               7            0.500000
# ...           ...                 ...
# 45568       49690            0.800000
# 45569       49691            0.430556
# 45570       49692            0.416667
# 45571       49693            0.440000
# 45572       49694            0.333333
#
#                                             product_name
# 0                             Chocolate Sandwich Cookies
# 1                                       All-Seasons Salt
# 2                   Robust Golden Unsweetened Oolong Tea
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4                         Pure Coconut Water With Orange
# ...                                                  ...
# 45568                      HIGH PERFORMANCE ENERGY DRINK
# ...

# %% [markdown]
# ### [C4] For each customer, what proportion of their products ordered are reorders?

# %% [markdown]
# ### [C5] What are the top 20 items that people put in their carts first?
